# %%
# %time %run -i ml-classification-comparison.py
# Out:
# ...
# EXERCISE 1: Single Dataset Comparison
# ...
#
# ✓ Data visualization saved
#
# Model Comparison Results:
#   Linear Regression Accuracy:   0.8380
#   Logistic Regression Accuracy: 0.8340
#   Difference:                   0.0040
#
# ...
# EXERCISE 2: 100 Simulations
# ...
#
# Results from 100 simulations:
#   Linear Regression:
#     Mean Accuracy: 0.8394 ± 0.0164
#   Logistic Regression:
#     Mean Accuracy: 0.8396 ± 0.0166
#   Average Difference: 0.0003
#
# ✓ Simulation results visualization saved
#
# ...
# EXERCISE 3: Accuracy vs Delta (Class Separation)
# ...
#
# Running 25 different deltas with 50 repetitions each...
# Total simulations: 1250
# ✓ Simulations complete
#
# ✓ Accuracy vs Delta visualization saved
#
# Key Findings:
# ----------------------------------------------------------------------
#
# Delta = 0.00:
#   Linear Regression:   0.5051 ± 0.0220
#   Logistic Regression: 0.5050 ± 0.0218
#   Difference:          -0.0001
#
# Delta = 1.50:
#   Linear Regression:   0.7714 ± 0.0166
# ...
